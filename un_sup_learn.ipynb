# %%
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
file = Path('crypto_data.csv')

# %%
data = pd.read_csv(file)
data
# Out:
#      Unnamed: 0        CoinName Algorithm  IsTrading ProofType  \
# 0            42         42 Coin    Scrypt       True   PoW/PoS
# 1           365         365Coin       X11       True   PoW/PoS
# 2           404         404Coin    Scrypt       True   PoW/PoS
# 3           611       SixEleven   SHA-256       True       PoW
# 4           808             808   SHA-256       True   PoW/PoS
# ...         ...             ...       ...        ...       ...
# 1247        XBC     BitcoinPlus    Scrypt       True       PoS
# 1248       DVTC      DivotyCoin    Scrypt      False   PoW/PoS
# 1249       GIOT     Giotto Coin    Scrypt      False   PoW/PoS
# 1250       OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS
# 1251       PUNK       SteamPunk       PoS      False       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# ...

# %%
data = data[data.IsTrading != False]
data.head()
# Out:
#   Unnamed: 0   CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42    42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 1        365    365Coin       X11       True   PoW/PoS              NaN
# 2        404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 3        611  SixEleven   SHA-256       True       PoW              NaN
# 4        808        808   SHA-256       True   PoW/PoS     0.000000e+00
#
#   TotalCoinSupply
# 0              42
# 1      2300000000
# 2       532000000
# 3          611000
# 4               0

# %%
data = data.drop('IsTrading', axis=1)
data.head()
# Out:
#   Unnamed: 0   CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42    42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 1        365    365Coin       X11   PoW/PoS              NaN      2300000000
# 2        404    404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 3        611  SixEleven   SHA-256       PoW              NaN          611000
# 4        808        808   SHA-256   PoW/PoS     0.000000e+00               0

# %%
data = data.dropna()
data.head()
# Out:
#   Unnamed: 0   CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42    42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 2        404    404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 4        808        808   SHA-256   PoW/PoS     0.000000e+00               0
# 5       1337  EliteCoin       X13   PoW/PoS     2.927942e+10    314159265359
# 7        BTC    Bitcoin   SHA-256       PoW     1.792718e+07        21000000

# %%
data = data[data.TotalCoinsMined > 0]
data.head()
# Out:
#   Unnamed: 0   CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42    42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 2        404    404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 5       1337  EliteCoin       X13   PoW/PoS     2.927942e+10    314159265359
# 7        BTC    Bitcoin   SHA-256       PoW     1.792718e+07        21000000
# 8        ETH   Ethereum    Ethash       PoW     1.076842e+08               0

# %%
data = data.drop(['CoinName', 'Unnamed: 0'], axis=1)
data.head()
# Out:
#   Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0    Scrypt   PoW/PoS     4.199995e+01              42
# 2    Scrypt   PoW/PoS     1.055185e+09       532000000
# 5       X13   PoW/PoS     2.927942e+10    314159265359
# 7   SHA-256       PoW     1.792718e+07        21000000
# 8    Ethash       PoW     1.076842e+08               0

# %%
dummy = pd.get_dummies(data[['Algorithm', 'ProofType']])
dummy.head()
# Out:
#    Algorithm_1GB AES Pattern Search  Algorithm_536  Algorithm_Argon2d  \
# 0                                 0              0                  0
# 2                                 0              0                  0
# 5                                 0              0                  0
# 7                                 0              0                  0
# 8                                 0              0                  0
#
#    Algorithm_BLAKE256  Algorithm_Blake  Algorithm_Blake2S  Algorithm_Blake2b  \
# 0                   0                0                  0                  0
# 2                   0                0                  0                  0
# 5                   0                0                  0                  0
# 7                   0                0                  0                  0
# 8                   0                0                  0                  0
#
#    Algorithm_C11  Algorithm_Cloverhash  Algorithm_Counterparty  ...  \
# ...

# %%
data = data.drop(data[['Algorithm', 'ProofType']], axis=1)
data.head()
# Out:
#    TotalCoinsMined TotalCoinSupply
# 0     4.199995e+01              42
# 2     1.055185e+09       532000000
# 5     2.927942e+10    314159265359
# 7     1.792718e+07        21000000
# 8     1.076842e+08               0

# %%
final = pd.concat([data,dummy], axis=1)
final.head()
# Out:
#    TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 0     4.199995e+01              42                                 0
# 2     1.055185e+09       532000000                                 0
# 5     2.927942e+10    314159265359                                 0
# 7     1.792718e+07        21000000                                 0
# 8     1.076842e+08               0                                 0
#
#    Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 0              0                  0                   0                0
# 2              0                  0                   0                0
# 5              0                  0                   0                0
# 7              0                  0                   0                0
# 8              0                  0                   0                0
#
#    Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  ...  \
# ...

# %%
scaler = StandardScaler()
final_scaled = scaler.fit_transform(final)

# num_columns = final_scaled.shape[1]

# final_scaled_df = pd.DataFrame(
#     data=final_scaled, columns=['PC%s' % _ for _ in range(num_columns)]
# )
# final_scaled_df.head()
# Out:
#         PC0       PC1       PC2       PC3       PC4      PC5       PC6  \
# 0 -0.117108 -0.152870 -0.043396 -0.043396 -0.043396 -0.06143 -0.075307
# 1 -0.093970 -0.145009 -0.043396 -0.043396 -0.043396 -0.06143 -0.075307
# 2  0.524946  4.489424 -0.043396 -0.043396 -0.043396 -0.06143 -0.075307
# 3 -0.116715 -0.152560 -0.043396 -0.043396 -0.043396 -0.06143 -0.075307
# 4 -0.114747 -0.152870 -0.043396 -0.043396 -0.043396 -0.06143 -0.075307
#
#         PC7      PC8      PC9  ...      PC88      PC89      PC90      PC91  \
# 0 -0.043396 -0.06143 -0.06143  ...  1.422226 -0.043396 -0.043396 -0.043396
# 1 -0.043396 -0.06143 -0.06143  ...  1.422226 -0.043396 -0.043396 -0.043396
# 2 -0.043396 -0.06143 -0.06143  ...  1.422226 -0.043396 -0.043396 -0.043396
# 3 -0.043396 -0.06143 -0.06143  ... -0.703123 -0.043396 -0.043396 -0.043396
# 4 -0.043396 -0.06143 -0.06143  ... -0.703123 -0.043396 -0.043396 -0.043396
#
#        PC92      PC93      PC94      PC95      PC96      PC97
# ...

# %%
pca = PCA(n_components=.90)

crypto_pca = pca.fit_transform(final_scaled)

# %%
crypto_pca.shape

# crypto_pca_df = pd.DataFrame(
#     data=crypto_pca, columns=['PC%s' % _ for _ in range(num_columns)]
# )
# crypto_pca_df.head()
# Out:
# (532, 74)

# %%
tsne = TSNE(learning_rate=35)
crypto_tsne = tsne.fit_transform(crypto_pca)

crypto_tsne.shape
# Out:
# (532, 2)

# %%
plt.scatter(crypto_tsne[:,0], crypto_tsne[:,1])
plt.show()

# %%
inertia = []
k = list(range(1, 11))

for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(crypto_tsne)
    inertia.append(km.inertia_)

elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.head()
# Out:
#    k        inertia
# 0  1  162329.921875
# 1  2   91270.140625
# 2  3   54767.367188
# 3  4   36739.960938
# 4  5   25082.501953

# %%
plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(range(1,11))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow curve for crypto data')
plt.show()

# %% [markdown]
# From my findings, it seems like the cryptocurrencies can be clustered. We can cluster them into 4 distinct clusters.
